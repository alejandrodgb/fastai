# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai import *
from fastai.vision import *

# %%
bs = 64

# %%
path = Path(Path.home()/'tutorials/data/distracted-driver/'); path
# Out:
# PosixPath('/home/jupyter/tutorials/data/distracted-driver')

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/tutorials/data/distracted-driver/driver_imgs_list.csv'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/models'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/test'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/valid'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/sample_submission.csv'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train_validation_files.p')]

# %%
img_list = pd.read_csv(path/'driver_imgs_list.csv')

# %%
img_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22424 entries, 0 to 22423
# Data columns (total 3 columns):
# subject      22424 non-null object
# classname    22424 non-null object
# img          22424 non-null object
# dtypes: object(3)
# memory usage: 525.6+ KB

# %%
img_list.head()
# Out:
#   subject classname            img
# 0    p002        c0  img_44733.jpg
# 1    p002        c0  img_72999.jpg
# 2    p002        c0  img_25094.jpg
# 3    p002        c0  img_69092.jpg
# 4    p002        c0  img_92629.jpg

# %%
# checking the training folder
(path/'train').ls()
# Out:
# [PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c8'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c9'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c1'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c5'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c7'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c6'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c2'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c3'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c0'),
#  PosixPath('/home/jupyter/tutorials/data/distracted-driver/train/c4')]

# %%
# checking distribution of classes
data_dist = np.array([[int(str(i)[-1:]),len(i.ls())] for i in (path/'train').ls()])
data_dist
# Out:
# array([[   8, 1707],
#        [   9, 1920],
#        [   1, 2043],
#        [   5, 2054],
#        [   7, 1781],
#        [   6, 2085],
#        [   2, 2091],
#        [   3, 2114],
#        [   0, 2199],
#        [   4, 2091]])

# %%
plt.bar(np.arange(len(data_dist)),
        data_dist[:,1],
        tick_label=data_dist[:,0]);

# %%
# validation data is not avaialble. Needs to be created

if os.path.isdir(path/'valid'):
    print('Validation data available.')
else:
    print('Creating validation data.')
    valid_ratio = 0.1
    moved_files = {}

    for f in (path/'train').ls():
        temp = []
        for i in f.ls():
            if random.random()<=valid_ratio:
                os.rename(str(i), str(i).replace('train','valid'))
                temp.append(str(i))
        moved_files[str(f)[-2:]]=temp
    
    mf_summ = np.array([[int(k[-1]),len(v)] for k,v in moved_files.items()])
    print('Folders with >.02 variance',
          (((mf_summ[:,1]/data_dist[:,1])-.1)>.02).sum())
# Out:
# Validation data available.

# %%
train_dist = np.array([[int(str(i)[-1:]),
                    len(i.ls())] for i in (path/'train').ls()])
valid_dist = np.array([[int(str(i)[-1:]),
                    len(i.ls())] for i in (path/'valid').ls()])

# %%
plt.subplot(121)
plt.bar(np.arange(len(train_dist)),
        train_dist[:,1],
        tick_label=train_dist[:,0]);
plt.title('Train Data')

plt.subplot(122)
plt.bar(np.arange(len(valid_dist)),
        valid_dist[:,1],
        tick_label=valid_dist[:,0]);
plt.title('Validation Data');

# %%
doc(get_transforms)

# %%
data = ImageDataBunch.from_folder(path, ds_tfms = get_transforms(), size=224,
                                  bs = bs, test='test').normalize(imagenet_stats)

# %%
data.show_batch(3, figsize=(7,6))

# %%
data.classes
# Out:
# ['c8', 'c9', 'c1', 'c5', 'c7', 'c6', 'c2', 'c3', 'c0', 'c4']

# %%
len(data.classes)==data.c
# Out:
# True

# %% [markdown]
# # Training

# %%
doc(create_cnn)

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
#learn.fit_one_cycle(4)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [2/4 03:11<03:11]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.509058</th>
#     <th>0.200316</th>
#     <th>0.061565</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.216249</th>
#     <th>0.094760</th>
#     <th>0.026507</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='314', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-495233eaf2b4> in <module>
# ----> 1 learn.fit_one_cycle(4)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      18     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      19                                         pct_start=pct_start, **kwargs))
# ---> 20     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      21
#      22 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     160         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     161         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 162             callbacks=self.callbacks+callbacks)
#     163
#     164     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      80             cb_handler.on_epoch_begin()
#      81
# ---> 82             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      83                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#      84                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      65             for i,o in enumerate(self._gen):
#      66                 yield o
# ---> 67                 if self.auto_update: self.update(i+1)
#      68         except:
#      69             self.on_interrupt()
#
# /opt/anaconda3/lib/python3.7/site-packages/fastprogress/fastprogress.py in update(self, val)
#      83             self.pred_t = avg_t * self.total
#      84             self.last_v,self.last_t = val,cur_t
# ---> 85             self.update_bar(val)
#      86             if not self.auto_update and val >= self.total:
#      87                 self.on_iter_end()
#
# /opt/anaconda3/lib/python3.7/site-packages/fastprogress/fastprogress.py in update_bar(self, val)
#      95             warn("Your generator is empty.")
#      96             self.on_update(0, '100% [0/0]')
# ---> 97         else: self.on_update(val, f'{100 * val/self.total:.2f}% [{val}/{self.total} {elapsed_t}<{remaining_t}{end}]')
#      98
#      99
#
# /opt/anaconda3/lib/python3.7/site-packages/fastprogress/fastprogress.py in on_update(self, val, text, interrupted)
#     169         if self.display:
#     170             self.out.update(HTML(self.progress))
# --> 171         elif self.parent is not None: self.parent.show()
#     172
#     173 class NBMasterBar(MasterBar):
#
# /opt/anaconda3/lib/python3.7/site-packages/fastprogress/fastprogress.py in show(self)
#     212         to_show = [name for name in self.order if name in self.inner_dict.keys()]
#     213         self.html_code = '\n'.join([self.inner_dict[n] for n in to_show])
# --> 214         self.out.update(HTML(self.html_code))
#     215
#     216     def write(self, line, table=False):
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in update(self, obj, **kwargs)
#     382             additional keyword arguments passed to update_display
#     383         """
# --> 384         update_display(obj, display_id=self.display_id, **kwargs)
#     385
#     386
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in update_display(obj, display_id, **kwargs)
#     332     """
#     333     kwargs['update'] = True
# --> 334     display(obj, display_id=display_id, **kwargs)
#     335
#     336
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     337                 printer = self.lookup(obj)
#     338             except KeyError:
# --> 339                 pass
#     340             else:
#     341                 return printer(obj)
#
# KeyboardInterrupt:

# %%
learn.load('stage-1');

# %%
#learn.save('stage-1')

# %%
doc(ClassificationInterpretation)

# %%
interp = ClassificationInterpretation.from_learner(learn, tta=True)
# Out:
# Total time: 01:17

# %%
data.test_ds
# Out:
# LabelList
# y: CategoryList (79726 items)
# [Category c8, Category c8, Category c8, Category c8, Category c8]...
# Path: /home/jupyter/tutorials/data/distracted-driver
# x: ImageItemList (79726 items)
# [Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640)]...
# Path: /home/jupyter/tutorials/data/distracted-driver

# %%
data.train_ds
# Out:
# LabelList
# y: CategoryList (20085 items)
# [Category c8, Category c8, Category c8, Category c8, Category c8]...
# Path: /home/jupyter/tutorials/data/distracted-driver
# x: ImageItemList (20085 items)
# [Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640)]...
# Path: /home/jupyter/tutorials/data/distracted-driver

# %%
data.valid_ds
# Out:
# LabelList
# y: CategoryList (2339 items)
# [Category c8, Category c8, Category c8, Category c8, Category c8]...
# Path: /home/jupyter/tutorials/data/distracted-driver
# x: ImageItemList (2339 items)
# [Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640), Image (3, 480, 640)]...
# Path: /home/jupyter/tutorials/data/distracted-driver

# %% [markdown]
# ### prediction of test ds

# %%
preds, y = learn.get_preds(DatasetType.Test)

# %%
preds.shape, y.shape
# Out:
# (torch.Size([79726, 10]), torch.Size([79726]))

# %%
with open(path/'predictions_test.p', 'wb') as f:
    pickle.dump(preds,f)
with open(path/'y_test.p', 'wb') as f:
    pickle.dump(y,f)

# %%
interp.top_losses()
# Out:
# (tensor([9.6931, 8.5884, 7.0452,  ..., -0.0000, -0.0000, -0.0000]),
#  tensor([ 924, 2087,  810,  ...,  842, 1784,  655]))

# %%
losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('c9', 'c0', 11), ('c6', 'c8', 6), ('c8', 'c9', 3)]

# %% [markdown]
# ## Finetunning

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 02:08
# epoch  train_loss  valid_loss  error_rate
# 1      0.114545    0.056507    0.016246    (02:08)

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
