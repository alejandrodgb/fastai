# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai import *
from fastai.vision import *

# %%
bs = 64

# %%
path = Path('/home/jupyter/tutorials/data/lesson1_exercise_data/'); path
# Out:
# PosixPath('/home/jupyter/tutorials/data/lesson1_exercise_data')

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/tutorials/data/lesson1_exercise_data/claude-monet.txt'),
#  PosixPath('/home/jupyter/tutorials/data/lesson1_exercise_data/van-gogh.txt'),
#  PosixPath('/home/jupyter/tutorials/data/lesson1_exercise_data/monet'),
#  PosixPath('/home/jupyter/tutorials/data/lesson1_exercise_data/vangogh')]
